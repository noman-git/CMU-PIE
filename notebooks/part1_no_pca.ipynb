# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import time

# %%
data = pd.read_csv('C:\\Users\\Noman\Desktop\\cowlar task 1\\data\\fea.csv', header=None)

# %%
def normalize_data(truncated_dataframe):
    """Normalize the data in the dataframe."""
    normalized_data_array = truncated_dataframe.values / np.linalg.norm(truncated_dataframe.values, axis=1, keepdims=True)
    norms = np.linalg.norm(normalized_data_array, axis=1, keepdims=True)
    return pd.DataFrame(normalized_data_array, columns=truncated_dataframe.columns)

# %%
# Constants
examples_per_label = 170
num_splits = 5

def create_df(dataframe, num_labels):
    """Create a dataframe with a specified number of labels."""
    labels = np.repeat(np.arange(num_labels), examples_per_label)
    dataframe = dataframe.iloc[:num_labels*examples_per_label].copy()
    dataframe['label'] = labels
    return dataframe

# %%
def create_data_splits(normalized_data_dataframe, num_labels, train_rows, test_rows, num_splits):
    """Create data splits for training and testing."""
    train_dfs_list = []
    test_dfs_list = []
    for i in range(num_splits):
        train_data = []
        test_data = []
        for label in range(num_labels):
            label_data = normalized_data_dataframe[normalized_data_dataframe['label'] == label].copy()
            train_label_data, test_label_data = train_test_split(label_data, train_size=train_rows, test_size=test_rows, random_state=i)
            train_data.append(train_label_data)
            test_data.append(test_label_data)
        train_dfs_list.append(pd.concat(train_data).sample(frac=1.0, random_state=i).reset_index(drop=True))
        test_dfs_list.append(pd.concat(test_data).sample(frac=1.0, random_state=i).reset_index(drop=True))
    return train_dfs_list, test_dfs_list

# %%
def process_data(num_labels, train_rows, test_rows):
    truncated_df = create_df(data, num_labels)
    return create_data_splits(truncated_df, num_labels, train_rows, test_rows, num_splits)

# %%
def extract_features_and_labels(dfs_list):
    X = [df.drop('label', axis=1).values for df in dfs_list]
    y = [df['label'].values for df in dfs_list]
    return X, y

# %%
labels_list = [10,7,5]
train_test_pairs = [(150, 20), (100, 70)]
data = normalize_data(data)
train_test_dfs = [process_data(num_labels, train_rows, test_rows) for num_labels in labels_list for train_rows, test_rows in train_test_pairs]
train_dfs_all, test_dfs_all = zip(*train_test_dfs)
X_train_all, y_train_all = zip(*[extract_features_and_labels(train_dfs_list) for train_dfs_list in train_dfs_all])
X_test_all, y_test_all = zip(*[extract_features_and_labels(test_dfs_list) for test_dfs_list in test_dfs_all])

# %%
import os
os.chdir('..')

# %%
from src.knn import KNNClassifier


# Create an empty DataFrame to store the results
results_df = pd.DataFrame(columns=["k_value", "distance_algo", "number_of_labels", "training_test_pair", "average_accuracy", "std_accuracy", "computation_time"])

for current_k in [3,5,7,9,11]:
    for distance in ['euclidean', 'manhattan', 'cosine']:
        knn_model = KNNClassifier(k=current_k, distance=distance)
        print(f'Results using k = {current_k} and distance measure of {distance}:')
        count = 0
        for X_train_splits, y_train_splits, X_test_splits, y_test_splits in zip(X_train_all, y_train_all, X_test_all, y_test_all):
            if count % 2 == 0:
                current_label = labels_list[count//2]
            current_training_examples, current_testing_values = train_test_pairs[count%2]
            count += 1
            accuracy_list = []
            start_time = time.time()
            for X_train, y_train, X_test, y_test in zip(X_train_splits, y_train_splits, X_test_splits, y_test_splits):
                knn_model.fit(X_train, y_train)
                y_pred = knn_model.predict(X_test)
                accuracy_list.append(np.mean(y_pred == y_test))
            end_time = time.time()
            computation_time = end_time - start_time
            print(computation_time)
            average_accuracy = np.mean(accuracy_list)
            std_accuracy = np.std(accuracy_list)
            print(f'Using {current_label} labels, {current_training_examples} training examples and {current_testing_values} test cases PER SUBJECT over 5 random splits:')
            print(f'Average accuracy: {average_accuracy:.3f}                           Standard deviation over accuracy: {std_accuracy:.3f}')
            print('------------------------------------------------------------------------------------------')
            
            # Append the results to the DataFrame
            results_to_append = pd.DataFrame({
                "k_value": [current_k],
                "distance_algo": [distance],
                "number_of_labels": [current_label],
                "training_test_pair": [f"{current_training_examples}_{current_testing_values}"],
                "average_accuracy": [average_accuracy],
                "std_accuracy": [std_accuracy],
                "computation_time": [computation_time]
            })
            results_df = pd.concat([results_df, results_to_append], ignore_index=True)
            
        print('==========================================================================================')
    print('==========================================================================================')
    print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    print('==========================================================================================')

# Save the DataFrame to a CSV file
results_df.to_csv("knn_results.csv", index=False)
# Out:
# Results using k = 3 and distance measure of euclidean:
# 11.663073778152466
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.964                           Standard deviation over accuracy: 0.028
# ------------------------------------------------------------------------------------------
# 43.18755602836609
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.967                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# 7.2812700271606445
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.964                           Standard deviation over accuracy: 0.024
# ------------------------------------------------------------------------------------------
# 14.424031019210815
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.967                           Standard deviation over accuracy: 0.010
# ------------------------------------------------------------------------------------------
# 2.532778263092041
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.978                           Standard deviation over accuracy: 0.019
# ------------------------------------------------------------------------------------------
# 5.9865312576293945
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.974                           Standard deviation over accuracy: 0.011
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 3 and distance measure of manhattan:
# 10.803557872772217
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.976                           Standard deviation over accuracy: 0.026
# ------------------------------------------------------------------------------------------
# 34.81516218185425
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.971                           Standard deviation over accuracy: 0.010
# ------------------------------------------------------------------------------------------
# 5.434354066848755
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.980                           Standard deviation over accuracy: 0.020
# ------------------------------------------------------------------------------------------
# 13.712562561035156
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.978                           Standard deviation over accuracy: 0.006
# ------------------------------------------------------------------------------------------
# 2.703524351119995
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.984                           Standard deviation over accuracy: 0.023
# ------------------------------------------------------------------------------------------
# 7.022854804992676
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.984                           Standard deviation over accuracy: 0.007
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 3 and distance measure of cosine:
# 0.7696292400360107
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.964                           Standard deviation over accuracy: 0.028
# ------------------------------------------------------------------------------------------
# 1.9182884693145752
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.967                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# 0.3115706443786621
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.964                           Standard deviation over accuracy: 0.024
# ------------------------------------------------------------------------------------------
# 0.6540868282318115
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.967                           Standard deviation over accuracy: 0.010
# ------------------------------------------------------------------------------------------
# 0.1530458927154541
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.978                           Standard deviation over accuracy: 0.019
# ------------------------------------------------------------------------------------------
# 0.37891459465026855
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.974                           Standard deviation over accuracy: 0.011
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ==========================================================================================
# Results using k = 5 and distance measure of euclidean:
# 11.610780715942383
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.956                           Standard deviation over accuracy: 0.033
# ------------------------------------------------------------------------------------------
# 36.821001052856445
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.957                           Standard deviation over accuracy: 0.010
# ------------------------------------------------------------------------------------------
# 5.025683403015137
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.946                           Standard deviation over accuracy: 0.033
# ------------------------------------------------------------------------------------------
# 12.784063816070557
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.958                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# 2.380758047103882
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.952                           Standard deviation over accuracy: 0.023
# ------------------------------------------------------------------------------------------
# 5.720102787017822
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.966                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 5 and distance measure of manhattan:
# 11.821558237075806
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.971                           Standard deviation over accuracy: 0.026
# ------------------------------------------------------------------------------------------
# 37.58878231048584
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.960                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# 5.816768407821655
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.970                           Standard deviation over accuracy: 0.030
# ------------------------------------------------------------------------------------------
# 13.605110168457031
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.966                           Standard deviation over accuracy: 0.004
# ------------------------------------------------------------------------------------------
# 2.8424036502838135
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.966                           Standard deviation over accuracy: 0.033
# ------------------------------------------------------------------------------------------
# 6.819332838058472
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.973                           Standard deviation over accuracy: 0.006
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 5 and distance measure of cosine:
# 0.7684710025787354
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.956                           Standard deviation over accuracy: 0.033
# ------------------------------------------------------------------------------------------
# 2.2201755046844482
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.957                           Standard deviation over accuracy: 0.010
# ------------------------------------------------------------------------------------------
# 0.3100733757019043
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.946                           Standard deviation over accuracy: 0.033
# ------------------------------------------------------------------------------------------
# 0.6679251194000244
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.958                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# 0.15976381301879883
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.952                           Standard deviation over accuracy: 0.023
# ------------------------------------------------------------------------------------------
# 0.34200024604797363
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.966                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ==========================================================================================
# Results using k = 7 and distance measure of euclidean:
# 11.979022979736328
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.934                           Standard deviation over accuracy: 0.037
# ------------------------------------------------------------------------------------------
# 32.54241943359375
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.946                           Standard deviation over accuracy: 0.010
# ------------------------------------------------------------------------------------------
# 4.958606958389282
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.933                           Standard deviation over accuracy: 0.036
# ------------------------------------------------------------------------------------------
# 12.222471952438354
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.949                           Standard deviation over accuracy: 0.007
# ------------------------------------------------------------------------------------------
# 2.3462276458740234
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.942                           Standard deviation over accuracy: 0.037
# ------------------------------------------------------------------------------------------
# 5.818298101425171
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.956                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 7 and distance measure of manhattan:
# 10.864860773086548
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.949                           Standard deviation over accuracy: 0.038
# ------------------------------------------------------------------------------------------
# 29.70603847503662
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.947                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# 5.007581472396851
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.957                           Standard deviation over accuracy: 0.036
# ------------------------------------------------------------------------------------------
# 11.934720993041992
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.956                           Standard deviation over accuracy: 0.005
# ------------------------------------------------------------------------------------------
# 2.378147840499878
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.964                           Standard deviation over accuracy: 0.029
# ------------------------------------------------------------------------------------------
# 5.75401759147644
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.963                           Standard deviation over accuracy: 0.011
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 7 and distance measure of cosine:
# 0.5985956192016602
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.934                           Standard deviation over accuracy: 0.037
# ------------------------------------------------------------------------------------------
# 1.4930758476257324
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.946                           Standard deviation over accuracy: 0.010
# ------------------------------------------------------------------------------------------
# 0.28318166732788086
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.933                           Standard deviation over accuracy: 0.036
# ------------------------------------------------------------------------------------------
# 0.6050021648406982
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.949                           Standard deviation over accuracy: 0.007
# ------------------------------------------------------------------------------------------
# 0.14200067520141602
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.942                           Standard deviation over accuracy: 0.037
# ------------------------------------------------------------------------------------------
# 0.3160734176635742
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.956                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ==========================================================================================
# Results using k = 9 and distance measure of euclidean:
# 10.315220594406128
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.929                           Standard deviation over accuracy: 0.043
# ------------------------------------------------------------------------------------------
# 28.543761730194092
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.939                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# 4.707579851150513
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.929                           Standard deviation over accuracy: 0.042
# ------------------------------------------------------------------------------------------
# 11.837503671646118
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.939                           Standard deviation over accuracy: 0.005
# ------------------------------------------------------------------------------------------
# 2.2740042209625244
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.930                           Standard deviation over accuracy: 0.038
# ------------------------------------------------------------------------------------------
# 5.642806768417358
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.949                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 9 and distance measure of manhattan:
# 10.671228647232056
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.947                           Standard deviation over accuracy: 0.034
# ------------------------------------------------------------------------------------------
# 29.30358076095581
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.943                           Standard deviation over accuracy: 0.011
# ------------------------------------------------------------------------------------------
# 4.853732347488403
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.951                           Standard deviation over accuracy: 0.035
# ------------------------------------------------------------------------------------------
# 11.871442556381226
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.950                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# 2.328009605407715
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.966                           Standard deviation over accuracy: 0.028
# ------------------------------------------------------------------------------------------
# 5.817631483078003
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.958                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 9 and distance measure of cosine:
# 0.5861930847167969
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.929                           Standard deviation over accuracy: 0.043
# ------------------------------------------------------------------------------------------
# 1.493983507156372
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.939                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# 0.2800159454345703
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.929                           Standard deviation over accuracy: 0.042
# ------------------------------------------------------------------------------------------
# 0.6080029010772705
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.939                           Standard deviation over accuracy: 0.005
# ------------------------------------------------------------------------------------------
# 0.14700698852539062
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.930                           Standard deviation over accuracy: 0.038
# ------------------------------------------------------------------------------------------
# 0.31813693046569824
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.949                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ==========================================================================================
# Results using k = 11 and distance measure of euclidean:
# 10.16817831993103
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.925                           Standard deviation over accuracy: 0.036
# ------------------------------------------------------------------------------------------
# 29.34027862548828
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.932                           Standard deviation over accuracy: 0.006
# ------------------------------------------------------------------------------------------
# 4.6120100021362305
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.923                           Standard deviation over accuracy: 0.039
# ------------------------------------------------------------------------------------------
# 11.7845618724823
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.931                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# 2.226088285446167
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.928                           Standard deviation over accuracy: 0.035
# ------------------------------------------------------------------------------------------
# 5.490029573440552
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.941                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 11 and distance measure of manhattan:
# 10.377949953079224
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.950                           Standard deviation over accuracy: 0.033
# ------------------------------------------------------------------------------------------
# 29.028590440750122
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.939                           Standard deviation over accuracy: 0.010
# ------------------------------------------------------------------------------------------
# 4.706309080123901
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.956                           Standard deviation over accuracy: 0.030
# ------------------------------------------------------------------------------------------
# 12.22598671913147
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.948                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# 2.238117218017578
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.966                           Standard deviation over accuracy: 0.031
# ------------------------------------------------------------------------------------------
# 5.493863105773926
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.957                           Standard deviation over accuracy: 0.007
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# Results using k = 11 and distance measure of cosine:
# 0.5889310836791992
# Using 10 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.925                           Standard deviation over accuracy: 0.036
# ------------------------------------------------------------------------------------------
# 1.7389717102050781
# Using 10 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.932                           Standard deviation over accuracy: 0.006
# ------------------------------------------------------------------------------------------
# 0.29271554946899414
# Using 7 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.923                           Standard deviation over accuracy: 0.039
# ------------------------------------------------------------------------------------------
# 0.6189775466918945
# Using 7 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.931                           Standard deviation over accuracy: 0.008
# ------------------------------------------------------------------------------------------
# 0.14503884315490723
# Using 5 labels, 150 training examples and 20 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.928                           Standard deviation over accuracy: 0.035
# ------------------------------------------------------------------------------------------
# 0.31600236892700195
# Using 5 labels, 100 training examples and 70 test cases PER SUBJECT over 5 random splits:
# Average accuracy: 0.941                           Standard deviation over accuracy: 0.009
# ------------------------------------------------------------------------------------------
# ==========================================================================================
# ==========================================================================================
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ==========================================================================================
